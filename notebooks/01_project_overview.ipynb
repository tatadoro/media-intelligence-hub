# %% [markdown]
# # Media Intelligence Hub — Обзор проекта
#
# В этом ноутбуке:
# - проверим, что окружение работает;
# - посмотрим конфигурацию;
# - сделаем набросок шагов анализа.

# %%
import pathlib
import yaml

PROJECT_ROOT = pathlib.Path().resolve().parent  # если ноутбук лежит в notebooks/
CONFIG_PATH = PROJECT_ROOT / "config" / "settings.yaml"

with open(CONFIG_PATH, "r", encoding="utf-8") as f:
    config = yaml.safe_load(f)

config
# Out:
# {'project_name': 'Media Intelligence Hub',
#  'data': {'raw_dir': 'data/raw', 'processed_dir': 'data/processed'}}
